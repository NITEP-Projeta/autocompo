# %%
import pandas as pd
import numpy as np

# %%
arquivo = pd.ExcelFile("PRO-009-25_REV 1 - PROPOSTA COMERCIAL.xlsx")

print(arquivo.sheet_names)
# Out:
# ['APR', 'CHECK', 'QQP', 'CPU  1 ', 'MO', 'EPIs', 'TREINAMENTOS', 'EXAMES', 'BDI-TRIBUTOS', 'ENCARGOS SOCIAIS']

# %%
meta = pd.read_excel("PRO-009-25_REV 1 - PROPOSTA COMERCIAL.xlsx", sheet_name="CPU  1 ", nrows=2, header=None)

# %%
identificador = meta.iloc[0, 5]

# %%
nome_coluna = meta.iloc[1, 5]

# %%
df = pd.read_excel("PRO-009-25_REV 1 - PROPOSTA COMERCIAL.xlsx", sheet_name="CPU  1 ", skiprows=5)
# Out:
# C:\Users\anderson.marley\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\anderson.marley\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Cód.',
#  'Discriminação',
#  'Unid',
#  'P.Unit',
#  'Quant',
#  'F.utiliz',
#  'Custo',
#  'Quant.1',
#  'F.utiliz.1',
#  'Custo.1',
#  'Quant.2',
#  'F.utiliz.2',
#  'Custo.2',
#  'Quant.3',
#  'F.utiliz.3',
#  'Custo.3',
#  'Quant.4',
#  'F.utiliz.4',
#  'Custo.4',
#  'Quant.5',
#  'F.utiliz.5',
#  'Custo.5',
#  'Quant.6',
#  'F.utiliz.6',
#  'Custo.6',
#  'Quant.7',
#  'F.utiliz.7',
#  'Custo.7',
#  'Quant.8',
#  'F.utiliz.8',
#  'Custo.8',
#  'Quant.9',
#  'F.utiliz.9',
#  'Custo.9',
#  'Quant.10',
#  'F.utiliz.10',
#  'Custo.10',
#  'Quant.11',
#  'F.utiliz.11',
#  'Custo.11',
#  'Quant.12',
#  'F.utiliz.12',
#  'Custo.12',
#  'Quant.13',
#  'F.utiliz.13',
#  'Custo.13',
#  'Quant.14',
#  'F.utiliz.14',
#  'Custo.14',
#  'Quant.15',
#  'F.utiliz.15',
#  'Custo.15',
#  'Quant.16',
#  'F.utiliz.16',
#  'Custo.16',
#  'Quant.17',
#  'F.utiliz.17',
#  'Custo.17',
#  'Quant.18',
#  'F.utiliz.18',
#  'Custo.18',
#  'Quant.19',
#  'F.utiliz.19',
#  'Custo.19',
# ...

# %%
data = df[['Cód.', 'Discriminação', 'Unid', 'P.Unit', 'Quant', 'F.utiliz', 'Custo']]

# %%
data['P.Unit'] = pd.to_numeric(data['P.Unit'], errors='coerce')
# Out:
# C:\Users\anderson.marley\AppData\Local\Temp\ipykernel_17368\2470204823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P.Unit'] = pd.to_numeric(data['P.Unit'], errors='coerce')

# %%
data['P.Unit'].isna().sum()
# Out:
# np.int64(75)

# %%
data = data.dropna(subset=['Unid', 'P.Unit'])

# %%
data['P.Unit'].isna().sum()
# Out:
# np.int64(0)

# %%
data['P.Unit'] = data['P.Unit'].round(2)

# %%
data['Identificador'] = identificador

# %%
data['Composicao'] = nome_coluna

# %%
data.head(20)
# Out:
#    Cód.                                      Discriminação    Unid    P.Unit  \
# 0   P01                                       Técnico SSMA      hh     30.03
# 1   P02                    Eletricista de força e controle      hh     35.64
# 2   P03                               Ajudante de elétrica      hh     21.21
# 3   P04                             Engenheiro eletricista      hh    122.13
# 4   P05  Engenheiro mecânico - Especialista em estrutur...      hh    122.13
# 5   P06                               Projetista (Cadista)      hh     28.53
# 6   P07         Alpinista industrial (Montador de andaime)      hh     34.67
# 7   P08                Encarregado de elétrica ou andaimes      hh     42.54
# 8   P09                   Montador de estruturas metálicas      hh     30.15
# 9   P10                                          Topógrafo      hh     31.03
# 10  P11                             Auxiliar de topografia      hh     16.52
# ...
